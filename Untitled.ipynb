# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('values.csv')
df2=pd.read_csv('labels.csv')

# %%
df.head()
# Out:
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     0z64un                                  1             normal
# 1     ryoo3j                                  2             normal
# 2     yt1s1x                                  1             normal
# 3     l2xjde                                  1  reversible_defect
# 4     oyt4ek                                  3  reversible_defect
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# ...

# %%
df=df.merge(df2,on='patient_id')

# %%
df.head()
# Out:
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     0z64un                                  1             normal
# 1     ryoo3j                                  2             normal
# 2     yt1s1x                                  1             normal
# 3     l2xjde                                  1  reversible_defect
# 4     oyt4ek                                  3  reversible_defect
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 0 to 179
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   patient_id                            180 non-null    object
#  1   slope_of_peak_exercise_st_segment     180 non-null    int64
#  2   thal                                  180 non-null    object
#  3   resting_blood_pressure                180 non-null    int64
#  4   chest_pain_type                       180 non-null    int64
#  5   num_major_vessels                     180 non-null    int64
#  6   fasting_blood_sugar_gt_120_mg_per_dl  180 non-null    int64
#  7   resting_ekg_results                   180 non-null    int64
#  8   serum_cholesterol_mg_per_dl           180 non-null    int64
#  9   oldpeak_eq_st_depression              180 non-null    float64
#  10  sex                                   180 non-null    int64
# ...

# %%
df=df.drop('patient_id',axis=1)

# %%
df.head()
# Out:
#    slope_of_peak_exercise_st_segment               thal  \
# 0                                  1             normal
# 1                                  2             normal
# 2                                  1             normal
# 3                                  1  reversible_defect
# 4                                  3  reversible_defect
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# 2                                     0                    2
# ...

# %%
df.nunique()
# Out:
# slope_of_peak_exercise_st_segment         3
# thal                                      3
# resting_blood_pressure                   36
# chest_pain_type                           4
# num_major_vessels                         4
# fasting_blood_sugar_gt_120_mg_per_dl      2
# resting_ekg_results                       3
# serum_cholesterol_mg_per_dl             118
# oldpeak_eq_st_depression                 34
# sex                                       2
# age                                      40
# max_heart_rate_achieved                  73
# exercise_induced_angina                   2
# heart_disease_present                     2
# dtype: int64

# %%
fig,axes = plt.subplots(3,5,figsize=(15,15))
n=0
m=0
for i in df.columns:
    sns.histplot(df,x=i,kde=True,ax=axes[n,m],hue='heart_disease_present')
    if(m>=4):
        n+=1
        m=0
    else:
        m+=1

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cmap='ocean')
# Out:
# <AxesSubplot:>

# %%
sns.histplot(df,x='serum_cholesterol_mg_per_dl',hue='heart_disease_present',stat='count',kde=True)
# Out:
# <AxesSubplot:xlabel='serum_cholesterol_mg_per_dl', ylabel='Count'>

# %%
sns.scatterplot(x='sex',y='age',data=df,hue='heart_disease_present')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
df['thal'].unique()
df['thal']=df['thal'].replace({'normal': 0, 'reversible_defect': 1, 'fixed_defect': 2})

# %%
df.head()
# Out:
#    slope_of_peak_exercise_st_segment  thal  resting_blood_pressure  \
# 0                                  1     0                     128
# 1                                  2     0                     110
# 2                                  1     0                     125
# 3                                  1     1                     152
# 4                                  3     1                     178
#
#    chest_pain_type  num_major_vessels  fasting_blood_sugar_gt_120_mg_per_dl  \
# 0                2                  0                                     0
# 1                3                  0                                     0
# 2                4                  3                                     0
# 3                4                  0                                     0
# 4                1                  0                                     0
#
#    resting_ekg_results  serum_cholesterol_mg_per_dl  oldpeak_eq_st_depression  \
# ...

# %%
sns.jointplot(x='resting_ekg_results',y='serum_cholesterol_mg_per_dl',data=df,hue='heart_disease_present')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score
y=df['heart_disease_present']
x=df.drop('heart_disease_present',axis=1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[-0.89124111, -0.8588975 , -0.19519463, ..., -1.05396422,
#          0.93248505, -0.68074565],
#        [ 0.72919727, -0.8588975 , -1.25631978, ..., -0.08713407,
#          0.38708356, -0.68074565],
#        [-0.89124111, -0.8588975 , -0.37204882, ...,  2.38365407,
#          0.56888406,  1.46897745],
#        ...,
#        [ 0.72919727,  0.8588975 , -0.37204882, ...,  0.98712164,
#         -0.8400698 ,  1.46897745],
#        [-0.89124111, -0.8588975 , -0.43100022, ..., -0.7316875 ,
#          1.15973567, -0.68074565],
#        [-0.89124111, -0.8588975 ,  1.69125009, ..., -0.08713407,
#          0.61433418, -0.68074565]])

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.25)

# %% [markdown]
# Model 1

# %%
from sklearn.linear_model import LogisticRegression
model1=LogisticRegression(max_iter = 200)
model1.fit(xtrain,ytrain)
ypred1 = model1.predict(xtest)

# %%
confusion_matrix(ypred1,ytest)
# Out:
# array([[26,  1],
#        [ 2, 16]], dtype=int64)

# %%
accuracy_score(ypred1,ytest)
# Out:
# 0.9333333333333333

# %% [markdown]
# Model 2

# %%
from sklearn.ensemble import RandomForestClassifier
model2=RandomForestClassifier(n_estimators=30)

# %%
model2.fit(xtrain,ytrain)
ypred2=model2.predict(xtest)
confusion_matrix(ypred2,ytest)
# Out:
# array([[28,  2],
#        [ 0, 15]], dtype=int64)

# %%
accuracy_score(ypred2,ytest)
# Out:
# 0.9555555555555556
